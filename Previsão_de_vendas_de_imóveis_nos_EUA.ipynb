# %% [markdown]
# <a href="https://colab.research.google.com/github/Thcataclismo/Portifolio-data-sciense/blob/main/Previs%C3%A3o_de_vendas_de_im%C3%B3veis_nos_EUA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #processamento de dados
import numpy as np #algebra linear
import matplotlib.pyplot as plt # criação de gráficos e visualizações de dados
import seaborn as sns #plotagem de gráficos estatísticos
import  warnings #mensagens de aviso
df = pd.read_csv('/content/drive/MyDrive/kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %% [markdown]
# VISUALIZAÇÃO DE DADOS

# %%
plt.figure(figsize=(12,6))
plt.subplot().ticklabel_format(useOffset=False,style='plain')
sns.distplot(df['price']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['bedrooms'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# id              -0.016762
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.subplot().ticklabel_format(useOffset=False,style='plain')
sns.scatterplot(x='price',y='sqft_living',data=df);

# %%
plt.figure(figsize=(12,6))
plt.subplot().ticklabel_format(useOffset=False,style='plain')
sns.boxplot(x='bedrooms',y='price',data=df);

# %% [markdown]
# Há uma mudança de 3 para 7 quartos...

# %%
plt.figure(figsize=(12,8))
plt.subplot().ticklabel_format(useOffset=False,style='plain')
sns.scatterplot(x='price', y='long',data=df);

# %% [markdown]
# Parece que a longitude -122,2 é uma área de habitação bastante cara.

# %%
plt.figure(figsize=(12,8))
plt.subplot().ticklabel_format(useOffset=False, style='plain')
sns.scatterplot(x='price', y='lat',data=df);

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long', y='lat', hue='price',data=df);

# %%
#Top 10 casas mais caras
df.sort_values('price',ascending=False).head(10)
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
# 2626  7738500731  20140815T000000  4500000.0         5       5.50
# 8638  3835500195  20140618T000000  4489000.0         4       3.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
#1% dos dados...
len(df)*0.01
# Out:
# 216.13

# %%
#inferior 99% dados...
non_top_1_perc=df.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',hue="price",edgecolor=None,alpha=0.2,palette='RdYlGn',data=non_top_1_perc);

# %%
plt.figure(figsize=(12,8))
plt.subplot().ticklabel_format(useOffset=False,style='plain')
sns.boxplot(x="waterfront",y="price",data=df);

# %% [markdown]
# Casas que ficam perto da orla, parece ser mais cara...

# %% [markdown]
# Engenharia de recursos

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df=df.drop('id', axis=1)

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, Length: 21613, dtype: datetime64[ns]

# %%
# ou podemos ultilizar a função LAMBDA
df['year']=df['date'].apply(lambda date: date.year)
df['month']=df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize=(12,8))
plt.subplot().ticklabel_format(useOffset=False, style='plain')
sns.boxplot(x='month',y='price',data=df);

# %%
plt.figure(figsize=(12,6))
df.groupby('month').mean()['price'].plot();

# %%
plt.figure(figsize=(12,6))
df.groupby('year').mean()['price'].plot();

# %%
df=df.drop('date',axis=1)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# ...

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %% [markdown]
# Temos 70 CEPs únicos... que são muitos

# %%
df=df.drop('zipcode',axis=1)

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0      13126
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
#Usamos valores aqui porque as redes neurais não funcionam tão bem em séries e dataframes...
X=df.drop('price',axis=1).values
Y=df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
#pré-processamento que coloca os dados na mesma escala
scaler=MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15129, 19)

# %%
model=Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))

model.compile(optimizer="adam",loss="mse")

# %%
#Usamos lotes, pois nossos dados são grandes..
model.fit(x=X_train,y=y_train,
          validation_data=(X_test,y_test),
         batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 2s 5ms/step - loss: 423623917568.0000 - val_loss: 432999333888.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 4ms/step - loss: 422441746432.0000 - val_loss: 428769378304.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 4ms/step - loss: 405550956544.0000 - val_loss: 389310939136.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 4ms/step - loss: 323673423872.0000 - val_loss: 256899350528.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 4ms/step - loss: 173244874752.0000 - val_loss: 121737289728.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 3ms/step - loss: 102260031488.0000 - val_loss: 103417266176.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 4ms/step - loss: 97467998208.0000 - val_loss: 101749800960.0000
# Epoch 8/400
# ...

# %%
losses=pd.DataFrame(model.history.history)

# %%
losses.plot(figsize=(12,6));

# %% [markdown]
# Não há overfitting aqui, pois a linha não sobe depois de chegar ao meio ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
predictions=model.predict(X_test)

# %%
predictions
# Out:
# array([[ 533808.94],
#        [ 647686.2 ],
#        [ 543726.56],
#        ...,
#        [ 410524.3 ],
#        [ 218541.66],
#        [1006188.  ]], dtype=float32)

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 167496.9181554297

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 104357.10502053131

# %%
df['price'].describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %% [markdown]
# Aqui podemos ver que nossa média é 5,400881e+05

# %%
 5.400881e+05
# Out:
# 540088.1

# %% [markdown]
# Este é o preço médio e o erro é de cerca de 10.000 dólares e estamos com um desconto de 20%

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.8006600798945357

# %%
plt.figure(figsize=(12,6))
plt.subplot().ticklabel_format(useOffset=False,style='plain')
plt.scatter(y_test,predictions);
plt.plot(y_test,y_test,'r');

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %% [markdown]
# Vamos fazer uma nova casa para prever o preço

# %%
single_house=df.drop('price',axis=1).iloc[0]

# %%
single_house=scaler.transform(single_house.values.reshape(-1,19))

# %%
model.predict(single_house)
# Out:
# array([[282850.53]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10
