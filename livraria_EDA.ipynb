# %% [markdown]
# <a href="https://colab.research.google.com/github/Thcataclismo/Portifolio-data-sciense/blob/main/livraria_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importando dados e bibliotecas 
import pandas as pd
import datetime as dt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/books_scraped.csv')
display(df)
# Out:
#                                                  Title       Book_category  \
# 0                                 A Light in the Attic              Poetry
# 1                                   Tipping the Velvet  Historical Fiction
# 2                                           Soumission             Fiction
# 3                                        Sharp Objects             Mystery
# 4                Sapiens: A Brief History of Humankind             History
# ..                                                 ...                 ...
# 995  Alice in Wonderland (Alice's Adventures in Won...            Classics
# 996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)      Sequential Art
# 997  A Spy's Devotion (The Regency Spies of London #1)  Historical Fiction
# 998                1st to Die (Women's Murder Club #1)             Mystery
# 999                 1,000 Places to See Before You Die              Travel
#
#     Star_rating  Price     Stock  Quantity
# ...

# %%
#analisando informações do conjunto de dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          1000 non-null   object
#  1   Book_category  1000 non-null   object
#  2   Star_rating    1000 non-null   object
#  3   Price          1000 non-null   float64
#  4   Stock          1000 non-null   object
#  5   Quantity       1000 non-null   int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 47.0+ KB

# %%
#verificando se existe algum valor nulo 
df.isnull().sum()
# Out:
# Title            0
# Book_category    0
# Star_rating      0
# Price            0
# Stock            0
# Quantity         0
# dtype: int64

# %%
#dados estatisticos do conjunto de dados
df.describe()
# Out:
#             Price     Quantity
# count  1000.00000  1000.000000
# mean     35.07035     8.585000
# std      14.44669     5.654622
# min      10.00000     1.000000
# 25%      22.10750     3.000000
# 50%      35.98000     7.000000
# 75%      47.45750    14.000000
# max      59.99000    22.000000

# %%
df.plot(kind='box',figsize=(10,6),subplots=True);

# %%
df.Title.value_counts()
# Out:
# The Star-Touched Queen                                        2
# A Light in the Attic                                          1
# Harry Potter and the Prisoner of Azkaban (Harry Potter #3)    1
# Some Women                                                    1
# Shopaholic Ties the Knot (Shopaholic #3)                      1
#                                                              ..
# Angels Walking (Angels Walking #1)                            1
# Angels & Demons (Robert Langdon #1)                           1
# All the Light We Cannot See                                   1
# Adulthood Is a Myth: A "Sarah's Scribbles" Collection         1
# 1,000 Places to See Before You Die                            1
# Name: Title, Length: 999, dtype: int64

# %%
#metricas de pontação
df['Star_rating'].value_counts()
# Out:
# One      226
# Three    203
# Five     196
# Two      196
# Four     179
# Name: Star_rating, dtype: int64

# %%
#viazao geral do estoque
df['Quantity'].hist();

# %%
#Quantidade predominante de estrelas por livro
df[df['Star_rating'] == df['Star_rating'].max()]
# Out:
#                                               Title Book_category Star_rating  \
# 10   Starving Hearts (Triangular Trade Trilogy, #1)       Default         Two
# 18                     Libertarianism for Beginners      Politics         Two
# 19                          It's Only the Himalayas        Travel         Two
# 21                                  How Music Works         Music         Two
# 36   Maude (1883-1993):She Grew Up with the country       Default         Two
# ..                                              ...           ...         ...
# 963                                 Of Mice and Men      Classics         Two
# 965            My Perfect Mistake (Over the Top #1)       Romance         Two
# 967                                     Meditations    Philosophy         Two
# 980                                    Frankenstein       Default         Two
# 983                                            Emma      Classics         Two
#
#      Price     Stock  Quantity
# ...

# %%
#top 10 livros com maior estoque
df.sort_values('Quantity',ascending=False).head(10)
# Out:
#                                                 Title       Book_category  \
# 0                                A Light in the Attic              Poetry
# 2                                          Soumission             Fiction
# 3                                       Sharp Objects             Mystery
# 4               Sapiens: A Brief History of Humankind             History
# 1                                  Tipping the Velvet  Historical Fiction
# 16                                               Olio              Poetry
# 27                     Aladdin and His Wonderful Lamp             Default
# 26  America's Cradle of Quarterbacks: Western Penn...             Default
# 25                      Birdsong: A Story in Pictures           Childrens
# 24                                         Black Dust             Romance
#
#    Star_rating  Price     Stock  Quantity
# 0        Three  51.77  In stock        22
# 2          One  50.10  In stock        20
# ...

# %%
#top 10 livro com menor estoque
df.sort_values('Quantity',ascending=True).head(10)
# Out:
#                                                  Title    Book_category  \
# 999                 1,000 Places to See Before You Die           Travel
# 927  The Mirror & the Maze (The Wrath and the Dawn ...          Fantasy
# 928                                  The Little Prince         Classics
# 929                         The Light of the Fireflies    Add a comment
# 930            The Last Girl (The Dominion Trilogy #1)  Science Fiction
# 931                                          The Iliad    Add a comment
# 932                           The Hook Up (Game On #1)        New Adult
# 933                                         The Haters      Young Adult
# 934                                  The Girl You Lost          Mystery
# 935          The Girl In The Ice (DCI Erika Foster #1)          Mystery
#
#     Star_rating  Price     Stock  Quantity
# 999        Five  26.08  In stock         1
# 927         One  29.38  In stock         1
# 928         Two  45.42  In stock         1
# ...

# %%
#top 10 livros mais caros
df.sort_values('Price',ascending=False).head(10)
# Out:
#                                                  Title   Book_category  \
# 648                 The Perfect Play (Play by Play #1)         Romance
# 617                  Last One Home (New Beginnings #1)         Fiction
# 860                   Civilization and Its Discontents      Psychology
# 560                     The Barefoot Contessa Cookbook  Food and Drink
# 366                          The Diary of a Young Girl      Nonfiction
# 657  The Bone Hunters (Lexy Vaughan & Steven Macaul...        Thriller
# 133  Thomas Jefferson and the Tripoli Pirates: The ...         History
# 387                      Boar Island (Anna Pigeon #19)         Mystery
# 549  The Man Who Mistook His Wife for a Hat and Oth...      Nonfiction
# 393                          The Improbability of Love         Fiction
#
#     Star_rating  Price     Stock  Quantity
# 648       Three  59.99  In stock         4
# 617       Three  59.98  In stock         5
# 860         Two  59.95  In stock         3
# ...

# %%
#top 10 livros com o menor preço
df.sort_values('Price',ascending=True).head(10)
# Out:
#                                                  Title   Book_category  \
# 638                         An Abundance of Katherines     Young Adult
# 501                              The Origin of Species         Science
# 716  The Tipping Point: How Little Things Can Make ...   Add a comment
# 84                                            Patience  Sequential Art
# 302                               Greek Mythic History         Default
# 558  The Fellowship of the Ring (The Lord of the Ri...         Default
# 479                                  History of Beauty             Art
# 242  The Lucifer Effect: Understanding How Good Peo...      Psychology
# 434  NaNo What Now? Finding your editing process, r...         Default
# 274                                       Pet Sematary          Horror
#
#     Star_rating  Price     Stock  Quantity
# 638        Five  10.00  In stock         5
# 501        Four  10.01  In stock         7
# 716         Two  10.02  In stock         3
# ...

# %%
#categoria predominante na livraria
df[df['Book_category'] == df['Book_category'].max()]
# Out:
#                                                  Title Book_category  \
# 5                                      The Requiem Red   Young Adult
# 12                                         Set Me Free   Young Adult
# 59   The Natural History of Us (The Fine Art of Pre...   Young Adult
# 89                                   Obsidian (Lux #1)   Young Adult
# 116                                            Burning   Young Adult
# 125                         A Fierce and Subtle Poison   Young Adult
# 172                     Scarlett Epstein Hates It Here   Young Adult
# 177                                  Nightingale, Sing   Young Adult
# 184  Library of Souls (Miss Peregrineâs Peculiar ...   Young Adult
# 190                     Frostbite (Vampire Academy #2)   Young Adult
# 218                                         Wild Swans   Young Adult
# 225            Until Friday Night (The Field Party #1)   Young Adult
# 229                              This Is Where It Ends   Young Adult
# ...

# %%
#livro com categoria menos predominante
df[df['Book_category'] == df['Book_category'].min()]
# Out:
#                                    Title Book_category Star_rating  Price  \
# 616  Logan Kade (Fallen Crest High #5.5)      Academic         Two  13.12
#
#         Stock  Quantity
# 616  In stock         5
